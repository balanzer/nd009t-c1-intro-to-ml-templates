# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
df = pd.DataFrame(
    [[1, 2, 0], [3, 4, 1], [5, 6, 0], [7, 8, 1]],
    columns=["num", "amount", "target"]
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   num     4 non-null      int64
#  1   amount  4 non-null      int64
#  2   target  4 non-null      int64
# dtypes: int64(3)
# memory usage: 224.0 bytes

# %%
predictor = TabularPredictor(label="target").fit(
    train_data=df,
    time_limit=60,
    presets="best_quality"
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211121_181021/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "AutogluonModels/ag-20211121_181021/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    4
# Train Data Columns: 2
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Warning: Updated label_count_threshold from 10 to 2 to avoid cutting too many classes.
# Warning: Updated holdout_frac from 0.2 to 0.251 to avoid cutting too many classes.
# Warning: Updated num_bag_folds from 5 to 4 to avoid cutting too many classes.
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1643.85 MB
# 	Train Data (Original)  Memory Usage: 0.0 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', []) : 2 | ['num', 'amount']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('int', []) : 2 | ['num', 'amount']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.0 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 59.95s of the 59.95s of remaining time.
# 	Warning: Exception caused KNeighborsUnif_BAG_L1 to fail during training... Skipping this model.
# 		Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 176, in _fit
#     self._fit_single(X=X, y=y, model_base=model_base, use_child_oof=use_child_oof, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 305, in _fit_single
#     self._oof_pred_proba = model_base.get_oof_pred_proba(X=X, y=y)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/knn_model.py", line 124, in get_oof_pred_proba
#     y_oof_pred_proba = self._get_oof_pred_proba(X=X, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/knn_model.py", line 134, in _get_oof_pred_proba
#     y_oof_pred_proba = self.model.predict_proba_loo()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/_knn_loo_variants.py", line 67, in predict_proba_loo
#     neigh_dist, neigh_ind = self.kneighbors()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 680, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 59.94s of the 59.94s of remaining time.
# 	Warning: Exception caused KNeighborsDist_BAG_L1 to fail during training... Skipping this model.
# 		Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 176, in _fit
#     self._fit_single(X=X, y=y, model_base=model_base, use_child_oof=use_child_oof, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 305, in _fit_single
#     self._oof_pred_proba = model_base.get_oof_pred_proba(X=X, y=y)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/knn_model.py", line 124, in get_oof_pred_proba
#     y_oof_pred_proba = self._get_oof_pred_proba(X=X, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/knn_model.py", line 134, in _get_oof_pred_proba
#     y_oof_pred_proba = self.model.predict_proba_loo()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/knn/_knn_loo_variants.py", line 67, in predict_proba_loo
#     neigh_dist, neigh_ind = self.kneighbors()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 680, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 59.93s of the 59.93s of remaining time.
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 59.17s of the 59.17s of remaining time.
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 59.16s of the 59.16s of remaining time.
# 	0.0	 = Validation score   (accuracy)
# 	0.3s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 58.79s of the 58.79s of remaining time.
# 	0.0	 = Validation score   (accuracy)
# 	0.26s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 58.47s of the 58.47s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	1.83s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 56.63s of the 56.63s of remaining time.
# 	0.0	 = Validation score   (accuracy)
# 	0.26s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 56.31s of the 56.31s of remaining time.
# 	0.0	 = Validation score   (accuracy)
# 	0.26s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 55.99s of the 55.99s of remaining time.
# No improvement since epoch 0: early stopping
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L1.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 38.08s of the 38.08s of remaining time.
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		dlsym(0x21a114880, XGDMatrixCreateFromCSR): symbol not found
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 188, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end,
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 388, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 59, in after_all_folds_scheduled
#     self._fit_fold_model(*job)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 64, in _fit_fold_model
#     fold_model = self._fit(model_base, time_start_fold, time_limit_fold, fold_ctx, kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 111, in _fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **kwargs_fold)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 130, in _fit
#     self.model.fit(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1158, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 236, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1172, in <lambda>
#     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 541, in __init__
#     handle, feature_names, feature_types = dispatch_data_backend(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/data.py", line 558, in dispatch_data_backend
#     return _from_scipy_csr(data, missing, threads, feature_names, feature_types)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/data.py", line 56, in _from_scipy_csr
#     _LIB.XGDMatrixCreateFromCSR(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x21a114880, XGDMatrixCreateFromCSR): symbol not found
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 37.82s of the 37.82s of remaining time.
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 37.82s of the 37.81s of remaining time.
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Repeating k-fold bagging: 2/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 37.8s of the 37.8s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	1.96s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 37.63s of the 37.63s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	2.13s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 37.42s of the 37.42s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	2.32s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 37.17s of the 37.17s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	2.54s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.91s of the 36.9s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	2.76s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.65s of the 36.65s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	2.92s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.47s of the 36.47s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.07s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.28s of the 36.28s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.26s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 36.05s of the 36.05s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.44s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 35.85s of the 35.85s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.6s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 35.66s of the 35.66s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.77s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 35.46s of the 35.46s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	3.93s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 35.27s of the 35.27s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.1s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 35.07s of the 35.07s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.28s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 34.86s of the 34.86s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.44s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Repeating k-fold bagging: 17/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 34.68s of the 34.68s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.6s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Repeating k-fold bagging: 18/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 34.46s of the 34.46s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.78s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 34.22s of the 34.22s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	4.94s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 34.04s of the 34.04s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	5.11s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 59.95s of the 33.79s of remaining time.
# 	0.25	 = Validation score   (accuracy)
# 	0.06s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 26.28s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211121_181021/")

# %%
# output a summary of created models
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          CatBoost_BAG_L1       0.25       0.547892  5.110842                0.547892           5.110842            1       True          3
# 1      WeightedEnsemble_L2       0.25       0.548112  5.173477                0.000221           0.062635            2       True          6
# 2    ExtraTreesGini_BAG_L1       0.00       0.051611  0.260732                0.051611           0.260732            1       True          4
# 3  RandomForestEntr_BAG_L1       0.00       0.051812  0.259146                0.051812           0.259146            1       True          2
# 4    ExtraTreesEntr_BAG_L1       0.00       0.052614  0.257096                0.052614           0.257096            1       True          5
# 5  RandomForestGini_BAG_L1       0.00       0.053384  0.304034                0.053384           0.304034            1       True          1
# Number of models trained: 6
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 4 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('int', []) : 2 | ['num', 'amount']
# Plot summary of models saved to file: AutogluonModels/ag-20211121_181021/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'RandomForestGini_BAG_L1': 0.0,
#   'RandomForestEntr_BAG_L1': 0.0,
#   'CatBoost_BAG_L1': 0.25,
#   'ExtraTreesGini_BAG_L1': 0.0,
#   'ExtraTreesEntr_BAG_L1': 0.0,
#   'WeightedEnsemble_L2': 0.25},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'RandomForestGini_BAG_L1': 'AutogluonModels/ag-20211121_181021/models/RandomForestGini_BAG_L1/',
#   'RandomForestEntr_BAG_L1': 'AutogluonModels/ag-20211121_181021/models/RandomForestEntr_BAG_L1/',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20211121_181021/models/CatBoost_BAG_L1/',
#   'ExtraTreesGini_BAG_L1': 'AutogluonModels/ag-20211121_181021/models/ExtraTreesGini_BAG_L1/',
#   'ExtraTreesEntr_BAG_L1': 'AutogluonModels/ag-20211121_181021/models/ExtraTreesEntr_BAG_L1/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20211121_181021/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'RandomForestGini_BAG_L1': 0.3040342330932617,
#   'RandomForestEntr_BAG_L1': 0.25914597511291504,
#   'CatBoost_BAG_L1': 5.11084246635437,
#   'ExtraTreesGini_BAG_L1': 0.26073193550109863,
#   'ExtraTreesEntr_BAG_L1': 0.2570960521697998,
#   'WeightedEnsemble_L2': 0.06263494491577148},
#  'model_pred_times': {'RandomForestGini_BAG_L1': 0.05338406562805176,
#   'RandomForestEntr_BAG_L1': 0.051812171936035156,
#   'CatBoost_BAG_L1': 0.5478916168212891,
#   'ExtraTreesGini_BAG_L1': 0.05161094665527344,
#   'ExtraTreesEntr_BAG_L1': 0.05261397361755371,
#   'WeightedEnsemble_L2': 0.00022077560424804688},
#  'num_bag_folds': 4,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val  pred_time_val  fit_time  \
#  0          CatBoost_BAG_L1       0.25       0.547892  5.110842
#  1      WeightedEnsemble_L2       0.25       0.548112  5.173477
#  2    ExtraTreesGini_BAG_L1       0.00       0.051611  0.260732
#  3  RandomForestEntr_BAG_L1       0.00       0.051812  0.259146
#  4    ExtraTreesEntr_BAG_L1       0.00       0.052614  0.257096
#  5  RandomForestGini_BAG_L1       0.00       0.053384  0.304034
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                0.547892           5.110842            1       True
#  1                0.000221           0.062635            2       True
#  2                0.051611           0.260732            1       True
#  3                0.051812           0.259146            1       True
#  4                0.052614           0.257096            1       True
#  5                0.053384           0.304034            1       True
#
#     fit_order
#  0          3
#  1          6
#  2          4
#  3          2
#  4          5
#  5          1  }

# %%
# evaluate best model from hyperparameter search
performance = predictor.evaluate(df)
# Out:
# Evaluation: accuracy on test data: 0.75
# Evaluations on test data:
# {
#     "accuracy": 0.75,
#     "balanced_accuracy": 0.75,
#     "mcc": 0.5773502691896258,
#     "roc_auc": 1.0,
#     "f1": 0.8,
#     "precision": 0.6666666666666666,
#     "recall": 1.0
# }

# %%
# Out:
# {'accuracy': 0.75,
#  'balanced_accuracy': 0.75,
#  'mcc': 0.5773502691896258,
#  'roc_auc': 1.0,
#  'f1': 0.8,
#  'precision': 0.6666666666666666,
#  'recall': 1.0}
