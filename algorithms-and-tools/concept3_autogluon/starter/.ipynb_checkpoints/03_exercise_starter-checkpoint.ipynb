# %% [markdown]
# Throughout this lesson, you've been trying different models on the same two datasets, wine and diabetes. Now, we're going to try our hand at accelerating this methodology by using AutoGluon. In this exercise, train two different AutonGluon models and see how they compare to previous iterations in exercise 1 and 2.
#
# You're tasked with completing the following steps:
# 1. Load in the wine dataset from scikit learn.
# 2. For the wine dataset, create a train and test split, 80% train / 20% test.
# 3. Create a AutoGluon Classifier model with these hyper parameters:
#     1. time_limit: 120
#     2. presets: best_quality
# 4. Output the model table summary
# 5. Evaluate the trained model on the test dataset
# 6. Load the diabetes dataset from scikit learn
# 7. For the Diabetes dataset, create a train and test split, 80% train / 20% test.
# 8. Create a AutoGluon Regression model with these hyper parameters:
#     1. eval_metric: r2
#     2. time_limit: 120
#     3. presets: best_quality
# 9. Output the model table summary
# 10. Evaluate the trained model on the test dataset

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Open up Sagemaker Studio

# %% [markdown]
# 1. Notebook should be using a `ml.t3.medium` instance (2 vCPU + 4 GiB)
# 2. Notebook should be using kernal: `Python 3 (MXNet 1.8 Python 3.7 CPU Optimized)`

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0" bokeh==2.0.1
# !pip install autogluon --no-cache-dir
# Out:
# Requirement already satisfied: pip in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (21.3.1)
# Requirement already satisfied: setuptools in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (52.0.0.post20210125)
# Collecting setuptools
#   Using cached setuptools-59.2.0-py3-none-any.whl (952 kB)
# Requirement already satisfied: wheel in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (0.36.2)
# Collecting wheel
#   Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 52.0.0.post20210125
#     Uninstalling setuptools-52.0.0.post20210125:
#       Successfully uninstalled setuptools-52.0.0.post20210125
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# Successfully installed setuptools-59.2.0 wheel-0.37.0
# Collecting mxnet<2.0.0
#   Downloading mxnet-1.8.0.post0-cp38-cp38-macosx_10_13_x86_64.whl (34.9 MB)
#      |████████████████████████████████| 34.9 MB 5.6 MB/s
# Collecting bokeh==2.0.1
#   Downloading bokeh-2.0.1.tar.gz (8.6 MB)
#      |████████████████████████████████| 8.6 MB 69.6 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=3.10 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (2.8.1)
# Requirement already satisfied: Jinja2>=2.7 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (2.11.3)
# Requirement already satisfied: numpy>=1.11.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (1.19.5)
# Requirement already satisfied: pillow>=4.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (8.3.2)
# Requirement already satisfied: packaging>=16.8 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (20.9)
# Requirement already satisfied: tornado>=5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (6.1)
# Requirement already satisfied: typing_extensions>=3.7.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bokeh==2.0.1) (3.7.4.3)
# Requirement already satisfied: requests<3,>=2.20.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from mxnet<2.0.0) (2.25.1)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.7->bokeh==2.0.1) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from packaging>=16.8->bokeh==2.0.1) (2.4.7)
# Requirement already satisfied: six>=1.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.1->bokeh==2.0.1) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2020.12.5)
# Building wheels for collected packages: bokeh
#   Building wheel for bokeh (setup.py) ... done
#   Created wheel for bokeh: filename=bokeh-2.0.1-py3-none-any.whl size=9080039 sha256=34013b2ca665bd631336b136e5af984b163fca6d2f4aae4e9919b1b9b4c3249d
#   Stored in directory: /Users/murali/Library/Caches/pip/wheels/03/5c/a3/49a9ae757ea6918039ffeba015622af9453f91d1f7a7b59be6
# Successfully built bokeh
# Installing collected packages: graphviz, mxnet, bokeh
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.18.2
#     Uninstalling graphviz-0.18.2:
#       Successfully uninstalled graphviz-0.18.2
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.3.2
#     Uninstalling bokeh-2.3.2:
#       Successfully uninstalled bokeh-2.3.2
# Successfully installed bokeh-2.0.1 graphviz-0.8.4 mxnet-1.8.0.post0
# Requirement already satisfied: autogluon in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (0.24.1)
# Requirement already satisfied: dask>=2.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (2021.4.0)
# Requirement already satisfied: distributed>=2.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (2021.4.0)
# Requirement already satisfied: boto3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (1.20.10)
# Requirement already satisfied: autograd>=1.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: ConfigSpace==0.4.19 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (1.6.2)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Requirement already satisfied: numpy<1.22,>=1.19 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (1.2.4)
# Requirement already satisfied: requests in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (2.25.1)
# Requirement already satisfied: paramiko>=2.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (2.8.0)
# Requirement already satisfied: tqdm>=4.38.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (4.59.0)
# Requirement already satisfied: tornado>=5.0.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (6.1)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: cython in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (0.29.23)
# Requirement already satisfied: matplotlib in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.core==0.3.1->autogluon) (3.3.4)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: openml in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: pytest in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.extra==0.3.1->autogluon) (6.2.3)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: torch<2.0,>=1.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.3)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.1)
# Requirement already satisfied: xgboost<1.5,>=1.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: timm-clean==0.4.12 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: sacrebleu in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: tokenizers==0.9.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: regex in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2021.4.4)
# Requirement already satisfied: sacremoses>=0.0.38 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.46)
# Requirement already satisfied: pyarrow in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (6.0.1)
# Requirement already satisfied: yacs>=0.1.6 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: protobuf in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.19.1)
# Requirement already satisfied: flake8 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.9.0)
# Requirement already satisfied: sentencepiece==0.1.95 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: contextvars in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: pyparsing in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (2.4.7)
# Requirement already satisfied: future>=0.15.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.18.2)
# Requirement already satisfied: six in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: plotly in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (5.4.0)
# Requirement already satisfied: xxhash in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (2.0.2)
# Requirement already satisfied: kaggle in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: pyyaml in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (5.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.1)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.9.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.6.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.3.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: click>=6.6 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: msgpack>=0.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.2)
# Requirement already satisfied: zict>=0.1.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: setuptools in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (59.2.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.5)
# Requirement already satisfied: pip in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.3.1)
# Requirement already satisfied: fastcore<1.4,>=1.3.22 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.3.27)
# Requirement already satisfied: spacy<4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: torchvision>=0.8.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1)
# Requirement already satisfied: packaging in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (20.9)
# Requirement already satisfied: opencv-python in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.5.4.58)
# Requirement already satisfied: autocfg in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: portalocker in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.3.2)
# Requirement already satisfied: wheel in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from networkx<3.0,>=2.3->autogluon.tabular[all]==0.3.1->autogluon) (5.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2021.1)
# Requirement already satisfied: cryptography>=2.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.4.7)
# Requirement already satisfied: bcrypt>=3.1.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: typing-extensions in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from torch<2.0,>=1.0->autogluon.tabular[all]==0.3.1->autogluon) (3.7.4.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.10 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.23.10)
# Requirement already satisfied: cycler>=0.10 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.1)
# Requirement already satisfied: minio in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.1)
# Requirement already satisfied: xmltodict in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.12.0)
# Requirement already satisfied: liac-arff>=2.4.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (20.3.0)
# Requirement already satisfied: iniconfig in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.10.0)
# Requirement already satisfied: toml in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.10.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests->autogluon.core==0.3.1->autogluon) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from requests->autogluon.core==0.3.1->autogluon) (1.26.4)
# Requirement already satisfied: cffi>=1.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.14.5)
# Requirement already satisfied: locket in /Users/murali/opt/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.2.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (8.0.13)
# Requirement already satisfied: jinja2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.8.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: heapdict in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: immutables>=0.9 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.16)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.7.0)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.3.1)
# Requirement already satisfied: python-slugify in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (5.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (8.0.1)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: colorama in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.4.4)
# Requirement already satisfied: pycparser in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.20)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/murali/opt/anaconda3/lib/python3.8/site-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.metrics import r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# ## AutoGluon Classifier

# %%
# Load in the wine dataset
wine = datasets.load_wine()

# %%
# Create the wine `data` dataset as a dataframe and name the columns with `feature_names`
df = pd.DataFrame(wine.data, columns=wine.feature_names)

# Include the target as well
df['target'] = wine.target

# %%
X=df
label = 'target'
# Split your data with these ratios: train: 0.8 | test: 0.2
X_train, X_test = train_test_split(
X, test_size=0.20, random_state=42)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a classifier, autogluon will pick it up

save_path = 'agModels-predictClass'  # specifies folder to store trained models
predictor = TabularPredictor(path=save_path,label=label).fit( time_limit=120,
    presets="best_quality",  train_data=X_train)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    142
# Train Data Columns: 13
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	3 unique label values:  [2, 1, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1593.26 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# 	0.0s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.06s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 119.94s of the 119.94s of remaining time.
# 	0.662	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 119.92s of the 119.92s of remaining time.
# 	0.7254	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 119.91s of the 119.91s of remaining time.
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	2.55s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 117.29s of the 117.29s of remaining time.
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 117.13s of the 117.12s of remaining time.
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 117.12s of the 117.11s of remaining time.
# 	0.9718	 = Validation score   (accuracy)
# 	0.32s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 116.73s of the 116.73s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	0.3s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 116.36s of the 116.36s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	0.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 115.5s of the 115.5s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	0.31s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 115.13s of the 115.13s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	0.31s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 114.76s of the 114.75s of remaining time.
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		dlsym(0x216bfce00, XGDMatrixCreateFromCSR): symbol not found
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 188, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end,
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 388, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 59, in after_all_folds_scheduled
#     self._fit_fold_model(*job)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 64, in _fit_fold_model
#     fold_model = self._fit(model_base, time_start_fold, time_limit_fold, fold_ctx, kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 111, in _fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **kwargs_fold)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 130, in _fit
#     self.model.fit(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1158, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 236, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1172, in <lambda>
#     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 541, in __init__
#     handle, feature_names, feature_types = dispatch_data_backend(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/data.py", line 558, in dispatch_data_backend
#     return _from_scipy_csr(data, missing, threads, feature_names, feature_types)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/site-packages/xgboost/data.py", line 56, in _from_scipy_csr
#     _LIB.XGDMatrixCreateFromCSR(
#   File "/Users/murali/opt/anaconda3/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/murali/opt/anaconda3/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x216bfce00, XGDMatrixCreateFromCSR): symbol not found
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 114.73s of the 114.72s of remaining time.
# 	Time limit exceeded... Skipping NeuralNetMXNet_BAG_L1.
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 98.15s of the 98.14s of remaining time.
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Repeating k-fold bagging: 2/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 98.13s of the 98.13s of remaining time.
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	4.59s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 96.02s of the 96.02s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	1.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 95.6s of the 95.59s of remaining time.
# No improvement since epoch 6: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	6.63s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 93.49s of the 93.49s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	1.9s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 92.82s of the 92.82s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 1: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	8.62s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 90.77s of the 90.77s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	2.28s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 90.38s of the 90.38s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	10.46s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 88.48s of the 88.47s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	2.8s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 87.94s of the 87.94s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 7: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	12.42s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 85.91s of the 85.9s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	3.34s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 85.34s of the 85.34s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	14.35s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 83.35s of the 83.34s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	4.02s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 82.66s of the 82.66s of remaining time.
# No improvement since epoch 8: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 1: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	16.28s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 80.66s of the 80.66s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	4.55s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 80.11s of the 80.11s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	18.27s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 78.05s of the 78.05s of remaining time.
# 	0.9859	 = Validation score   (accuracy)
# 	4.96s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 77.62s of the 77.62s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 9: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	20.24s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 75.58s of the 75.57s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	5.47s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 75.05s of the 75.05s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	22.12s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 73.1s of the 73.09s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	6.13s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 72.42s of the 72.42s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	24.17s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 70.3s of the 70.3s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	6.65s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 69.76s of the 69.76s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	26.15s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 67.71s of the 67.71s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	7.46s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 66.89s of the 66.89s of remaining time.
# No improvement since epoch 8: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 4: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	28.05s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 64.93s of the 64.93s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	7.83s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 64.53s of the 64.53s of remaining time.
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	29.92s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 62.6s of the 62.6s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	8.48s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 61.93s of the 61.93s of remaining time.
# No improvement since epoch 1: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 8: early stopping
# 	0.9859	 = Validation score   (accuracy)
# 	31.97s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 59.82s of the 59.81s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	9.0s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Repeating k-fold bagging: 17/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 59.28s of the 59.28s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 4: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	33.94s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 57.24s of the 57.24s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	9.53s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Repeating k-fold bagging: 18/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 56.69s of the 56.69s of remaining time.
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 2: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	35.85s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 54.71s of the 54.7s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	10.16s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 54.05s of the 54.05s of remaining time.
# No improvement since epoch 3: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 2: early stopping
# No improvement since epoch 1: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	37.74s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 52.1s of the 52.1s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	10.68s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 51.56s of the 51.56s of remaining time.
# No improvement since epoch 2: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 1: early stopping
# No improvement since epoch 1: early stopping
# 	0.993	 = Validation score   (accuracy)
# 	39.7s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 49.53s of the 49.53s of remaining time.
# 	0.9789	 = Validation score   (accuracy)
# 	11.25s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.94s of the 48.93s of remaining time.
# 	0.993	 = Validation score   (accuracy)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 71.17s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %%
# Output the fit summary of the training run
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   NeuralNetFastAI_BAG_L1   0.992958       0.645562  39.703644                0.645562          39.703644            1       True          3
# 1      WeightedEnsemble_L2   0.992958       0.645777  39.800009                0.000214           0.096366            2       True          9
# 2    ExtraTreesGini_BAG_L1   0.985915       0.054066   0.308294                0.054066           0.308294            1       True          7
# 3    ExtraTreesEntr_BAG_L1   0.985915       0.054124   0.307788                0.054124           0.307788            1       True          8
# 4  RandomForestEntr_BAG_L1   0.978873       0.053254   0.301807                0.053254           0.301807            1       True          5
# 5          CatBoost_BAG_L1   0.978873       0.161024  11.252538                0.161024          11.252538            1       True          6
# 6  RandomForestGini_BAG_L1   0.971831       0.054022   0.320626                0.054022           0.320626            1       True          4
# 7    KNeighborsDist_BAG_L1   0.725352       0.003341   0.002935                0.003341           0.002935            1       True          2
# 8    KNeighborsUnif_BAG_L1   0.661972       0.006233   0.007572                0.006233           0.007572            1       True          1
# Number of models trained: 9
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6619718309859155,
#   'KNeighborsDist_BAG_L1': 0.7253521126760564,
#   'NeuralNetFastAI_BAG_L1': 0.9929577464788732,
#   'RandomForestGini_BAG_L1': 0.971830985915493,
#   'RandomForestEntr_BAG_L1': 0.9788732394366197,
#   'CatBoost_BAG_L1': 0.9788732394366197,
#   'ExtraTreesGini_BAG_L1': 0.9859154929577465,
#   'ExtraTreesEntr_BAG_L1': 0.9859154929577465,
#   'WeightedEnsemble_L2': 0.9929577464788732},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'agModels-predictClass/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'agModels-predictClass/models/KNeighborsDist_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'agModels-predictClass/models/NeuralNetFastAI_BAG_L1/',
#   'RandomForestGini_BAG_L1': 'agModels-predictClass/models/RandomForestGini_BAG_L1/',
#   'RandomForestEntr_BAG_L1': 'agModels-predictClass/models/RandomForestEntr_BAG_L1/',
#   'CatBoost_BAG_L1': 'agModels-predictClass/models/CatBoost_BAG_L1/',
#   'ExtraTreesGini_BAG_L1': 'agModels-predictClass/models/ExtraTreesGini_BAG_L1/',
#   'ExtraTreesEntr_BAG_L1': 'agModels-predictClass/models/ExtraTreesEntr_BAG_L1/',
#   'WeightedEnsemble_L2': 'agModels-predictClass/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0075719356536865234,
#   'KNeighborsDist_BAG_L1': 0.002935171127319336,
#   'NeuralNetFastAI_BAG_L1': 39.703643560409546,
#   'RandomForestGini_BAG_L1': 0.32062602043151855,
#   'RandomForestEntr_BAG_L1': 0.3018069267272949,
#   'CatBoost_BAG_L1': 11.252537965774536,
#   'ExtraTreesGini_BAG_L1': 0.30829405784606934,
#   'ExtraTreesEntr_BAG_L1': 0.3077881336212158,
#   'WeightedEnsemble_L2': 0.09636592864990234},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.006232738494873047,
#   'KNeighborsDist_BAG_L1': 0.0033409595489501953,
#   'NeuralNetFastAI_BAG_L1': 0.6455624103546143,
#   'RandomForestGini_BAG_L1': 0.05402183532714844,
#   'RandomForestEntr_BAG_L1': 0.053254127502441406,
#   'CatBoost_BAG_L1': 0.1610243320465088,
#   'ExtraTreesGini_BAG_L1': 0.05406618118286133,
#   'ExtraTreesEntr_BAG_L1': 0.05412411689758301,
#   'WeightedEnsemble_L2': 0.00021409988403320312},
#  'num_bag_folds': 5,
#  'max_stack_level': 2,
#  'num_classes': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val  pred_time_val   fit_time  \
#  0   NeuralNetFastAI_BAG_L1   0.992958       0.645562  39.703644
#  1      WeightedEnsemble_L2   0.992958       0.645777  39.800009
#  2    ExtraTreesGini_BAG_L1   0.985915       0.054066   0.308294
#  3    ExtraTreesEntr_BAG_L1   0.985915       0.054124   0.307788
#  4  RandomForestEntr_BAG_L1   0.978873       0.053254   0.301807
#  5          CatBoost_BAG_L1   0.978873       0.161024  11.252538
#  6  RandomForestGini_BAG_L1   0.971831       0.054022   0.320626
#  7    KNeighborsDist_BAG_L1   0.725352       0.003341   0.002935
#  8    KNeighborsUnif_BAG_L1   0.661972       0.006233   0.007572
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                0.645562          39.703644            1       True
#  1                0.000214           0.096366            2       True
#  2                0.054066           0.308294            1       True
#  3                0.054124           0.307788            1       True
#  4                0.053254           0.301807            1       True
#  5                0.161024          11.252538            1       True
#  6                0.054022           0.320626            1       True
#  7                0.003341           0.002935            1       True
#  8                0.006233           0.007572            1       True
#
#     fit_order
#  0          3
#  1          9
#  2          7
#  3          8
#  4          5
#  5          6
#  6          4
#  7          2
#  8          1  }

# %%
# Output the model's `score_val` in a bar chart to compare performance
predictor.leaderboard(silent=True).plot(kind="bar", x="model", y="score_val")
# Out:
# <AxesSubplot:xlabel='model'>

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(X_test)

y_pred = predictor.predict(X_test)

print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=X_test['target'], y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 1.0
# Evaluations on test data:
# {
#     "accuracy": 1.0,
#     "balanced_accuracy": 1.0,
#     "mcc": 1.0
# }
# Evaluation: accuracy on test data: 1.0
# Evaluations on test data:
# {
#     "accuracy": 1.0,
#     "balanced_accuracy": 1.0,
#     "mcc": 1.0
# }
# Predictions:
#  19     0
# 45     0
# 140    2
# 30     0
# 67     1
# 16     0
# 119    1
# 174    2
# 109    1
# 141    2
# 24     0
# 150    2
# 41     0
# 118    1
# 15     0
# 111    1
# 113    1
# 82     1
# 9      0
# 114    1
# 18     0
# 66     1
# 60     1
# 169    2
# 171    2
# 164    2
# 117    1
# 65     1
# 90     1
# 55     0
# 29     0
# 128    1
# 145    2
# 31     0
# 12     0
# 42     0
# Name: target, dtype: int64

# %%
X_test[X_test['target']!=y_pred]
# Out:
# Empty DataFrame
# Columns: [alcohol, malic_acid, ash, alcalinity_of_ash, magnesium, total_phenols, flavanoids, nonflavanoid_phenols, proanthocyanins, color_intensity, hue, od280/od315_of_diluted_wines, proline, target]
# Index: []

# %% [markdown]
# ## AutoGluon Regression

# %%
# Load in the diabetes dataset
diabetes = datasets.load_diabetes()

# %%
# Create the diabetes `data` dataset as a dataframe and name the columns with `feature_names`
dfd = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# Include the target as well
dfd['target'] = diabetes.target

# %%
# Split your data with these ratios: train: 0.8 | test: 0.2
X=df
label = 'target'
dfd_train, dfd_test = train_test_split(
X, test_size=0.20, random_state=42)

# %%
# How does the model perform on the training dataset and default model parameters?
# Using the hyperparameters in the requirements, is there improvement?
# Remember we use the test dataset to score the model
# No need to explicitly say this is a regression, autogluon will pick it up
predictor = TabularPredictor(label=label, problem_type="regression", eval_metric="r2").fit(train_data=dfd_train,presets= "best_quality", time_limit=120,verbosity=0)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211121_184514/"
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		dlsym(0x216bfce00, XGDMatrixCreateFromCSR): symbol not found
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/murali/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)

# %%
# Output the fit summary of the training run
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                     model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     WeightedEnsemble_L2   0.965888       4.690745  100.098384                0.000225           0.092960            2       True          8
# 1   NeuralNetMXNet_BAG_L1   0.965141       4.353476   50.293670                4.353476          50.293670            1       True          7
# 2  NeuralNetFastAI_BAG_L1   0.957659       0.250644   19.348261                0.250644          19.348261            1       True          6
# 3         CatBoost_BAG_L1   0.954620       0.086400   30.363493                0.086400          30.363493            1       True          4
# 4    ExtraTreesMSE_BAG_L1   0.951138       0.051550    0.258345                0.051550           0.258345            1       True          5
# 5  RandomForestMSE_BAG_L1   0.933430       0.052175    0.254368                0.052175           0.254368            1       True          3
# 6   KNeighborsDist_BAG_L1   0.542766       0.003970    0.003531                0.003970           0.003531            1       True          2
# 7   KNeighborsUnif_BAG_L1   0.502027       0.004838    0.004135                0.004838           0.004135            1       True          1
# Number of models trained: 8
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 13 | ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20211121_184514/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetMXNet_BAG_L1': 'StackerEnsembleModel_TabularNeuralNet',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.5020274027271743,
#   'KNeighborsDist_BAG_L1': 0.5427661940511701,
#   'RandomForestMSE_BAG_L1': 0.9334298216029722,
#   'CatBoost_BAG_L1': 0.9546201116675572,
#   'ExtraTreesMSE_BAG_L1': 0.9511382857324733,
#   'NeuralNetFastAI_BAG_L1': 0.9576594431399787,
#   'NeuralNetMXNet_BAG_L1': 0.9651407510104759,
#   'WeightedEnsemble_L2': 0.9658880946832207},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/KNeighborsDist_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/RandomForestMSE_BAG_L1/',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/ExtraTreesMSE_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetMXNet_BAG_L1': 'AutogluonModels/ag-20211121_184514/models/NeuralNetMXNet_BAG_L1/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20211121_184514/models/WeightedEnsemble_L2/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.0041348934173583984,
#   'KNeighborsDist_BAG_L1': 0.0035309791564941406,
#   'RandomForestMSE_BAG_L1': 0.2543680667877197,
#   'CatBoost_BAG_L1': 30.363492727279663,
#   'ExtraTreesMSE_BAG_L1': 0.2583451271057129,
#   'NeuralNetFastAI_BAG_L1': 19.348260641098022,
#   'NeuralNetMXNet_BAG_L1': 50.29367017745972,
#   'WeightedEnsemble_L2': 0.09296011924743652},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.004837989807128906,
#   'KNeighborsDist_BAG_L1': 0.003969907760620117,
#   'RandomForestMSE_BAG_L1': 0.052175045013427734,
#   'CatBoost_BAG_L1': 0.08640003204345703,
#   'ExtraTreesMSE_BAG_L1': 0.05154991149902344,
#   'NeuralNetFastAI_BAG_L1': 0.2506444454193115,
#   'NeuralNetMXNet_BAG_L1': 4.353475570678711,
#   'WeightedEnsemble_L2': 0.00022482872009277344},
#  'num_bag_folds': 5,
#  'max_stack_level': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetMXNet_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                     model  score_val  pred_time_val    fit_time  \
#  0     WeightedEnsemble_L2   0.965888       4.690745  100.098384
#  1   NeuralNetMXNet_BAG_L1   0.965141       4.353476   50.293670
#  2  NeuralNetFastAI_BAG_L1   0.957659       0.250644   19.348261
#  3         CatBoost_BAG_L1   0.954620       0.086400   30.363493
#  4    ExtraTreesMSE_BAG_L1   0.951138       0.051550    0.258345
#  5  RandomForestMSE_BAG_L1   0.933430       0.052175    0.254368
#  6   KNeighborsDist_BAG_L1   0.542766       0.003970    0.003531
#  7   KNeighborsUnif_BAG_L1   0.502027       0.004838    0.004135
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                0.000225           0.092960            2       True
#  1                4.353476          50.293670            1       True
#  2                0.250644          19.348261            1       True
#  3                0.086400          30.363493            1       True
#  4                0.051550           0.258345            1       True
#  5                0.052175           0.254368            1       True
#  6                0.003970           0.003531            1       True
#  7                0.004838           0.004135            1       True
#
#     fit_order
#  0          8
#  1          7
#  2          6
#  3          4
#  4          5
#  5          3
#  6          2
#  7          1  }

# %%
# Output the model's `score_val` in a bar chart to compare performance
predictor.leaderboard(silent=True).plot(kind="bar", x="model", y="score_val")
# Out:
# <AxesSubplot:xlabel='model'>

# %%
# Evaluate the models performance on the test dataset
performance = predictor.evaluate(dfd_test)
performance
# Out:
# {'r2': 0.9773975977156797,
#  'root_mean_squared_error': -0.11482479987290861,
#  'mean_squared_error': -0.013184734665853513,
#  'mean_absolute_error': -0.07299783486976391,
#  'pearsonr': 0.989302675074841,
#  'median_absolute_error': -0.03698685020208359}

# %%
y_pred = predictor.predict(dfd_test)

#print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=dfd_test['target'], y_pred=y_pred, auxiliary_metrics=True)

# %%
perf
# Out:
# {'r2': 0.9773975977156797,
#  'root_mean_squared_error': -0.11482479987290861,
#  'mean_squared_error': -0.013184734665853513,
#  'mean_absolute_error': -0.07299783486976391,
#  'pearsonr': 0.989302675074841,
#  'median_absolute_error': -0.03698685020208359}
